# %% [markdown]
# <a href="https://colab.research.google.com/github/tanya12181/Machine-Learning-Internship-at-Internity/blob/main/Creating_csv_file_out_of_images_dataset_in_json_format.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import seaborn
import urllib.request as ur

# %%
df= pd.read_json('face_detection[1].json',lines=True)
image_links = df['content']
df
# Out:
#                                                content  ... extras
# 0    http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 1    http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 2    http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 3    http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 4    http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# ..                                                 ...  ...    ...
# 404  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 405  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 406  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 407  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 408  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
#
# [409 rows x 3 columns]

# %%
import csv
with open('images_url.csv', 'w',newline='') as file:
  writer = csv.writer(file)
  writer.writerow(["content"])
  for link in image_links:
    writer.writerow([link])
# with open('images.csv','r',newline='') as file:
#   reader = csv.reader(file)
#   for r in reader:
#     print(r)

# %%
#Function for retrieving images from its url and storing it 
#in the specificed file path
#images are numbered (for instance, as image-1.jpg)
def imageFromURL(i,url,file_path):
  file_name=f"image-{i}.jpg"
  full_path=f"{file_path}{file_name}"
  ur.urlretrieve(url,full_path)

# %%
file_name='images_url.csv'
file_path='images/'
urls = pd.read_csv(file_name)
img_no=1
for url in urls['content']:
  if (url!='content'):
    imageFromURL(img_no,url,file_path)
    img_no+=1

# %%
#creating an images folder and then creating a .zip version out of it
#then only we can download the folder
# !zip -r /content/images.zip /content/images
from google.colab import files
files.download("/content/images.zip")
# Out:
#   adding: content/images/ (stored 0%)
#   adding: content/images/image-307.jpg (deflated 0%)
#   adding: content/images/image-308.jpg (deflated 0%)
#   adding: content/images/image-77.jpg (deflated 1%)
#   adding: content/images/image-227.jpg (deflated 0%)
#   adding: content/images/image-289.jpg (deflated 0%)
#   adding: content/images/image-120.jpg (deflated 1%)
#   adding: content/images/image-381.jpg (deflated 0%)
#   adding: content/images/image-39.jpg (deflated 0%)
#   adding: content/images/image-151.jpg (deflated 1%)
#   adding: content/images/image-71.jpg (deflated 0%)
#   adding: content/images/image-395.jpg (deflated 1%)
#   adding: content/images/image-171.jpg (deflated 3%)
#   adding: content/images/image-155.jpg (deflated 5%)
#   adding: content/images/image-105.jpg (deflated 1%)
#   adding: content/images/image-89.jpg (deflated 0%)
#   adding: content/images/image-206.jpg (deflated 2%)
#   adding: content/images/image-271.jpg (deflated 0%)
# ...
