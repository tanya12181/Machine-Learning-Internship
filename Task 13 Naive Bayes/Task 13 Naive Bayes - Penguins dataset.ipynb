# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#sns.get_dataset_names()

# %%
df = sns.load_dataset('penguins')
print(df)
labels = np.unique(np.array(df['species']))
labels
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
cnt = df['sex'].value_counts().index[0]
df['sex']=df['sex'].fillna(cnt)
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN    Male
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN    Male
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
df = df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
# Encoding the categorical values with integers
# {'Adelie': 1, 'Chinstrap': 2, 'Gentoo': 3} species
# {'Biscoe': 1, 'Dream': 2, 'Torgersen': 3} islands
# {'Male':1, 'Female':2}
# species=np.unique(df['species'])
# island = np.unique(df['island'])
# idx=1
# d1,d2={},{}
# for s in species:
#     d1[s]=str(idx)
#     idx+=1 

# idx=1
# for i in island:
#     d2[i]=str(idx)
#     idx+=1

# encode={'species':d1,'island':d2,'sex':{'Male':1, 'Female':2}}
# df=df.replace(encode)
# df

# %%
# df.dtypes

# %%
# splitting dataset in 80:20 ratio as train and test set respectively
# species is the response variable i.e. column 0
idx = 8*df.shape[0]//10
df = np.array(df)
np.random.shuffle(df)
x_train=df[:idx,1:]
y_train=df[:idx,0]
x_test=df[idx:,1:] 
y_test=df[idx:,0] 
print("\nx train:\n",x_train)
print("\ny train:\n",y_train)
print("\nx test:\n",x_test)
print("\ny test:\n",y_test)
# Out:
# x train:
#  [['Torgersen' 41.1 18.6 189.0 3325.0 'Male']
#  ['Dream' 41.1 17.5 190.0 3900.0 'Male']
#  ['Biscoe' 45.3 13.8 208.0 4200.0 'Female']
#  ...
#  ['Torgersen' 43.1 19.2 197.0 3500.0 'Male']
#  ['Dream' 38.9 18.8 190.0 3600.0 'Female']
#  ['Torgersen' 42.8 18.5 195.0 4250.0 'Male']]
#
# y train:
#  ['Adelie' 'Adelie' 'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Adelie' 'Gentoo'
#  'Gentoo' 'Adelie' 'Gentoo' 'Gentoo' 'Gentoo' 'Chinstrap' 'Adelie'
#  'Chinstrap' 'Chinstrap' 'Gentoo' 'Gentoo' 'Adelie' 'Gentoo' 'Chinstrap'
#  'Gentoo' 'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Gentoo' 'Chinstrap'
#  'Chinstrap' 'Adelie' 'Gentoo' 'Gentoo' 'Adelie' 'Gentoo' 'Chinstrap'
#  'Gentoo' 'Adelie' 'Chinstrap' 'Adelie' 'Gentoo' 'Chinstrap' 'Chinstrap'
#  'Adelie' 'Gentoo' 'Adelie' 'Adelie' 'Chinstrap' 'Adelie' 'Adelie'
#  'Adelie' 'Adelie' 'Gentoo' 'Gentoo' 'Gentoo' 'Gentoo' 'Chinstrap'
#  'Gentoo' 'Adelie' 'Chinstrap' 'Adelie' 'Gentoo' 'Chinstrap' 'Gentoo'
#  'Gentoo' 'Adelie' 'Gentoo' 'Gentoo' 'Adelie' 'Chinstrap' 'Chinstrap'
#  'Adelie' 'Chinstrap' 'Gentoo' 'Adelie' 'Adelie' 'Chinstrap' 'Adelie'
#  'Chinstrap' 'Adelie' 'Adelie' 'Adelie' 'Adelie' 'Gentoo' 'Chinstrap'
#  'Chinstrap' 'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Gentoo' 'Adelie'
#  'Gentoo' 'Chinstrap' 'Gentoo' 'Adelie' 'Chinstrap' 'Chinstrap' 'Adelie'
#  'Adelie' 'Gentoo' 'Chinstrap' 'Adelie' 'Gentoo' 'Adelie' 'Adelie'
#  'Chinstrap' 'Gentoo' 'Chinstrap' 'Adelie' 'Gentoo' 'Gentoo' 'Chinstrap'
#  'Gentoo' 'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Gentoo' 'Adelie' 'Gentoo'
#  'Adelie' 'Gentoo' 'Adelie' 'Chinstrap' 'Gentoo' 'Chinstrap' 'Adelie'
#  'Adelie' 'Chinstrap' 'Adelie' 'Gentoo' 'Gentoo' 'Chinstrap' 'Gentoo'
#  'Gentoo' 'Adelie' 'Chinstrap' 'Adelie' 'Gentoo' 'Gentoo' 'Adelie'
#  'Chinstrap' 'Chinstrap' 'Adelie' 'Gentoo' 'Chinstrap' 'Adelie' 'Adelie'
#  'Gentoo' 'Adelie' 'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Adelie' 'Gentoo'
#  'Gentoo' 'Gentoo' 'Gentoo' 'Adelie' 'Gentoo' 'Chinstrap' 'Chinstrap'
#  'Gentoo' 'Adelie' 'Adelie' 'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Gentoo'
#  'Chinstrap' 'Adelie' 'Gentoo' 'Adelie' 'Chinstrap' 'Gentoo' 'Adelie'
#  'Gentoo' 'Adelie' 'Adelie' 'Chinstrap' 'Adelie' 'Chinstrap' 'Gentoo'
#  'Adelie' 'Adelie' 'Adelie' 'Gentoo' 'Chinstrap' 'Chinstrap' 'Adelie'
#  'Adelie' 'Chinstrap' 'Gentoo' 'Adelie' 'Chinstrap' 'Chinstrap'
#  'Chinstrap' 'Adelie' 'Gentoo' 'Gentoo' 'Adelie' 'Adelie' 'Gentoo'
#  'Adelie' 'Gentoo' 'Gentoo' 'Adelie' 'Adelie' 'Gentoo' 'Adelie' 'Gentoo'
#  'Adelie' 'Adelie' 'Gentoo' 'Adelie' 'Chinstrap' 'Gentoo' 'Gentoo'
#  'Chinstrap' 'Chinstrap' 'Adelie' 'Gentoo' 'Adelie' 'Gentoo' 'Gentoo'
#  'Adelie' 'Adelie' 'Chinstrap' 'Chinstrap' 'Adelie' 'Adelie' 'Chinstrap'
#  'Adelie' 'Adelie' 'Gentoo' 'Adelie' 'Chinstrap' 'Adelie' 'Gentoo'
#  'Gentoo' 'Chinstrap' 'Gentoo' 'Adelie' 'Adelie' 'Gentoo' 'Chinstrap'
#  'Adelie' 'Gentoo' 'Adelie' 'Chinstrap' 'Adelie' 'Adelie' 'Gentoo'
#  'Gentoo' 'Adelie' 'Adelie' 'Gentoo' 'Gentoo' 'Chinstrap' 'Gentoo'
#  'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Adelie' 'Chinstrap' 'Adelie'
#  'Adelie' 'Adelie' 'Adelie']
#
# x test:
#  [['Biscoe' 46.2 14.5 209.0 4800.0 'Female']
#  ['Dream' 45.2 16.6 191.0 3250.0 'Female']
#  ['Biscoe' 51.5 16.3 230.0 5500.0 'Male']
#  ['Biscoe' 50.4 15.3 224.0 5550.0 'Male']
#  ['Dream' 37.0 16.9 185.0 3000.0 'Female']
#  ['Biscoe' 49.1 14.8 220.0 5150.0 'Female']
#  ['Biscoe' 46.1 13.2 211.0 4500.0 'Female']
#  ['Dream' 40.3 18.5 196.0 4350.0 'Male']
#  ['Dream' 46.5 17.9 192.0 3500.0 'Female']
#  ['Biscoe' 48.8 16.2 222.0 6000.0 'Male']
#  ['Biscoe' 46.8 16.1 215.0 5500.0 'Male']
#  ['Dream' 43.2 18.5 192.0 4100.0 'Male']
#  ['Biscoe' 37.8 20.0 190.0 4250.0 'Male']
#  ['Biscoe' 45.5 13.7 214.0 4650.0 'Female']
#  ['Dream' 38.1 18.6 190.0 3700.0 'Female']
#  ['Biscoe' 42.6 13.7 213.0 4950.0 'Female']
#  ['Torgersen' 41.8 19.4 198.0 4450.0 'Male']
#  ['Biscoe' 47.5 14.2 209.0 4600.0 'Female']
#  ['Biscoe' 51.1 16.3 220.0 6000.0 'Male']
#  ['Dream' 52.0 18.1 201.0 4050.0 'Male']
#  ['Biscoe' 42.8 14.2 209.0 4700.0 'Female']
#  ['Torgersen' 37.8 17.1 186.0 3300.0 'Male']
#  ['Biscoe' 35.9 19.2 189.0 3800.0 'Female']
#  ['Dream' 49.0 19.6 212.0 4300.0 'Male']
#  ['Biscoe' 45.1 14.4 210.0 4400.0 'Female']
#  ['Dream' 41.1 18.1 205.0 4300.0 'Male']
#  ['Torgersen' 40.6 19.0 199.0 4000.0 'Male']
#  ['Biscoe' 45.6 20.3 191.0 4600.0 'Male']
#  ['Biscoe' 46.5 13.5 210.0 4550.0 'Female']
#  ['Biscoe' 42.2 19.5 197.0 4275.0 'Male']
#  ['Biscoe' 36.4 17.1 184.0 2850.0 'Female']
#  ['Dream' 49.5 19.0 200.0 3800.0 'Male']
#  ['Dream' 36.4 17.0 195.0 3325.0 'Female']
#  ['Biscoe' 43.5 14.2 220.0 4700.0 'Female']
#  ['Torgersen' 37.2 19.4 184.0 3900.0 'Male']
#  ['Torgersen' 35.1 19.4 193.0 4200.0 'Male']
#  ['Biscoe' 50.8 17.3 228.0 5600.0 'Male']
#  ['Biscoe' 50.2 14.3 218.0 5700.0 'Male']
#  ['Biscoe' 49.8 15.9 229.0 5950.0 'Male']
#  ['Dream' 37.6 19.3 181.0 3300.0 'Female']
#  ['Biscoe' 50.8 15.7 226.0 5200.0 'Male']
#  ['Dream' 43.5 18.1 202.0 3400.0 'Female']
#  ['Biscoe' 49.6 16.0 225.0 5700.0 'Male']
#  ['Biscoe' 38.2 20.0 190.0 3900.0 'Male']
#  ['Dream' 39.5 17.8 188.0 3300.0 'Female']
#  ['Biscoe' 47.5 14.0 212.0 4875.0 'Female']
#  ['Torgersen' 40.2 17.0 176.0 3450.0 'Female']
#  ['Biscoe' 40.1 18.9 188.0 4300.0 'Male']
#  ['Biscoe' 51.3 14.2 218.0 5300.0 'Male']
#  ['Dream' 36.3 19.5 190.0 3800.0 'Male']
#  ['Biscoe' 54.3 15.7 231.0 5650.0 'Male']
#  ['Biscoe' 42.9 13.1 215.0 5000.0 'Female']
#  ['Biscoe' 43.3 14.0 208.0 4575.0 'Female']
#  ['Biscoe' 49.4 15.8 216.0 4925.0 'Male']
#  ['Biscoe' 46.5 14.5 213.0 4400.0 'Female']
#  ['Dream' 39.6 18.1 186.0 4450.0 'Male']
#  ['Torgersen' 39.2 19.6 195.0 4675.0 'Male']
#  ['Dream' 52.0 19.0 197.0 4150.0 'Male']
#  ['Dream' 37.0 16.5 185.0 3400.0 'Female']
#  ['Biscoe' 43.2 14.5 208.0 4450.0 'Female']
#  ['Biscoe' 44.4 17.3 219.0 5250.0 'Male']
#  ['Torgersen' 38.6 21.2 191.0 3800.0 'Male']
#  ['Biscoe' 35.0 17.9 192.0 3725.0 'Female']
#  ['Biscoe' 39.0 17.5 186.0 3550.0 'Female']
#  ['Dream' 54.2 20.8 201.0 4300.0 'Male']
#  ['Biscoe' 40.6 18.6 183.0 3550.0 'Male']
#  ['Dream' 37.3 17.8 191.0 3350.0 'Female']
#  ['Biscoe' 46.4 15.0 216.0 4700.0 'Female']
#  ['Dream' 39.6 18.8 190.0 4600.0 'Male']]
#
# y test:
#  ['Gentoo' 'Chinstrap' 'Gentoo' 'Gentoo' 'Adelie' 'Gentoo' 'Gentoo'
#  'Adelie' 'Chinstrap' 'Gentoo' 'Gentoo' 'Adelie' 'Adelie' 'Gentoo'
#  'Adelie' 'Gentoo' 'Adelie' 'Gentoo' 'Gentoo' 'Chinstrap' 'Gentoo'
#  'Adelie' 'Adelie' 'Chinstrap' 'Gentoo' 'Adelie' 'Adelie' 'Adelie'
#  'Gentoo' 'Adelie' 'Adelie' 'Chinstrap' 'Adelie' 'Gentoo' 'Adelie'
#  'Adelie' 'Gentoo' 'Gentoo' 'Gentoo' 'Adelie' 'Gentoo' 'Chinstrap'
#  'Gentoo' 'Adelie' 'Adelie' 'Gentoo' 'Adelie' 'Adelie' 'Gentoo' 'Adelie'
#  'Gentoo' 'Gentoo' 'Gentoo' 'Gentoo' 'Gentoo' 'Adelie' 'Adelie'
#  'Chinstrap' 'Adelie' 'Gentoo' 'Gentoo' 'Adelie' 'Adelie' 'Adelie'
#  'Chinstrap' 'Adelie' 'Adelie' 'Gentoo' 'Adelie']

# %%
from math import sqrt

#finds mean and standard deviation for each column.Also stores columns 
#with continuous values

def find_stats(x):
    #{c:[] for c in range(x.shape[1])}
    mean,std,columns=[],[],[]
    for col in range(x.shape[1]):
        if isinstance(x[0,col],str)==False:
            mean.append(np.mean(x[:,col]))
            std.append(np.std(x[:,col]))
            columns.append(col)
    return mean,std,columns


#finds probability for category variables
# P(Class|Type) = P(Class)*P(Type|Class)/P(Type)

def find_category_prob(x,y,cls):
    n = x.shape[0]
    
    #type_prob={}#P(Type)
    class_prob=0
    for i in range(n):
        if y[i]==cls:
            class_prob+=1
    class_prob/=n
    
    probabilities={}
    columns=[]
    for col in range(x.shape[1]):
        if isinstance(x[0,col],str):
            columns.append(col)
            
    probabilities={c:None for c in columns}
    
    for col in columns:
        types,counts=np.unique(x[:,col],return_counts=True)

        p={t:0 for t in types} #P(Type|Class)

        for r in range(n):
            if y[r]==cls:
                p[x[r,col]]+=1

        for i in range(types.shape[0]):
            p[types[i]]=np.log(p[types[i]]/counts[i])
            p[types[i]]-=np.log(counts[i]/n)
            p[types[i]]+=np.log(class_prob)
            #type_prob[types[i]]=counts[i]/n
        probabilities[col]=p
        
    return probabilities
    
    
# We find mean and standard deviation for each class
# cls is variable to store the class

def stats_by_class(x,y):
    classes = np.unique(y)
    groups={c:[] for c in classes}
    for row in range(y.shape[0]):
        c = y[row]
        groups[c].append(x[row,:])
    stats={}
    category_prob={}
    for cls,rows in groups.items():
        category_prob[cls]=find_category_prob(x,y,cls)
        mean,std,col = find_stats(np.array(rows))
        stats[cls]=[mean,std,col,len(rows)]
    return stats,category_prob
    
    

    
def gaussian_prob(x_i,mean,std):
    return (1/(sqrt(2*np.pi)*std))*np.exp((-1*(x_i-mean)**2)/(2*(std**2)))



def find_prob_for_class(stats,row,category_prob=None):
    total_rows=0
    for key in stats.keys():
        total_rows+=stats[key][3]
    prob={}
    for cls in stats.keys():
        prob[cls]=np.log(stats[cls][3]/total_rows)
        
        if category_prob is not None:
            d1 = category_prob[cls]
        for key in d1.keys():
            d2 = d1[key]
            prob[cls]+=d2[row[key]]
        
        for i in range(len(stats[cls][0])):
            mean = stats[cls][0][i]
            std = stats[cls][1][i]
            idx = stats[cls][2][i]
            #print(mean,std)
            prob[cls]+=np.log(gaussian_prob(row[idx],mean,std))
    return prob


def predict(stats,test_row,category_prob=None):
    prob=find_prob_for_class(stats,category_prob,test_row)
    print(prob)
    label,best_prob=None,None
    for key in prob.keys():
        if best_prob is None or best_prob<prob[key]:
            best_prob=prob[key]
            label=key
    return label



def calAccuracy(pred,y_):
    correct=0
    for i in range(y_.shape[0]):
        if pred[i]==y_[i]:
            correct+=1
    return correct*100/y_.shape[0]

def showPredict(pred,y_):
    for i in range(len(pred)):
        print("predicted: ",pred[i],end="\t")
        print("actual: ",y_[i])

# %%
stats,cat_prob = stats_by_class(x_train,y_train)
#print(cat_prob)
predictions=[]
for r in range(x_test.shape[0]):
    label = predict(stats,cat_prob,x_test[r,:])
    predictions.append(label)

#print(predictions)
accuracy = calAccuracy(predictions, y_test)
print(f"model's accuracy: {accuracy}%")
# Out:
# {'Adelie': -31.8538104193046, 'Chinstrap': -inf, 'Gentoo': -17.21606904570624}
# {'Adelie': -19.484358853628216, 'Chinstrap': -20.575213721327344, 'Gentoo': -inf}
# {'Adelie': -54.94233334720623, 'Chinstrap': -inf, 'Gentoo': -20.166696175262622}
# {'Adelie': -50.32193901537303, 'Chinstrap': -inf, 'Gentoo': -17.417027953046805}
# {'Adelie': -17.563011302354035, 'Chinstrap': -27.936965228764485, 'Gentoo': -inf}
# {'Adelie': -43.00338551550598, 'Chinstrap': -inf, 'Gentoo': -16.261873799801524}
# {'Adelie': -34.948277381434636, 'Chinstrap': -inf, 'Gentoo': -19.13769113771359}
# {'Adelie': -17.22330465697835, 'Chinstrap': -22.61732661843262, 'Gentoo': -inf}
# {'Adelie': -19.495701976664165, 'Chinstrap': -18.35107467751334, 'Gentoo': -inf}
# {'Adelie': -49.92993440156256, 'Chinstrap': -inf, 'Gentoo': -18.830275606503154}
# {'Adelie': -37.76156388998659, 'Chinstrap': -inf, 'Gentoo': -17.040867721612653}
# {'Adelie': -17.29678287426962, 'Chinstrap': -19.948197207508912, 'Gentoo': -inf}
# {'Adelie': -18.017078741599242, 'Chinstrap': -inf, 'Gentoo': -46.35633269571947}
# {'Adelie': -34.98565178910267, 'Chinstrap': -inf, 'Gentoo': -17.68367125355813}
# {'Adelie': -15.37429406538902, 'Chinstrap': -23.325317003141645, 'Gentoo': -inf}
# {'Adelie': -34.169950632169005, 'Chinstrap': -inf, 'Gentoo': -18.530319269574463}
# {'Adelie': -17.035065990836124, 'Chinstrap': -inf, 'Gentoo': -inf}
# {'Adelie': -32.9791680209809, 'Chinstrap': -inf, 'Gentoo': -17.648516699018813}
# {'Adelie': -51.8833993762167, 'Chinstrap': -inf, 'Gentoo': -19.38376045866081}
# {'Adelie': -28.98232002552459, 'Chinstrap': -19.07921577440136, 'Gentoo': -inf}
# {'Adelie': -29.44612790604723, 'Chinstrap': -inf, 'Gentoo': -18.673542480586928}
# {'Adelie': -14.708303067197072, 'Chinstrap': -inf, 'Gentoo': -inf}
# {'Adelie': -16.860611184494807, 'Chinstrap': -inf, 'Gentoo': -46.873766109760254}
# {'Adelie': -29.51815379096202, 'Chinstrap': -22.434322425999177, 'Gentoo': -inf}
# {'Adelie': -29.572340700528635, 'Chinstrap': -inf, 'Gentoo': -18.058438950715708}
# {'Adelie': -19.36469651980098, 'Chinstrap': -22.770863230097582, 'Gentoo': -inf}
# {'Adelie': -15.268497888990325, 'Chinstrap': -inf, 'Gentoo': -inf}
# {'Adelie': -22.87199038350822, 'Chinstrap': -inf, 'Gentoo': -41.74605265458466}
# {'Adelie': -34.135034480531495, 'Chinstrap': -inf, 'Gentoo': -18.56009435756829}
# {'Adelie': -18.882573374207254, 'Chinstrap': -inf, 'Gentoo': -35.745284975396174}
# {'Adelie': -18.90870461051184, 'Chinstrap': -inf, 'Gentoo': -48.9280436402304}
# {'Adelie': -24.52172878460839, 'Chinstrap': -18.281126006082264, 'Gentoo': -inf}
# {'Adelie': -16.808161053788368, 'Chinstrap': -26.153250327786168, 'Gentoo': -inf}
# {'Adelie': -35.8714765739092, 'Chinstrap': -inf, 'Gentoo': -17.607401706314246}
# {'Adelie': -14.79678441765881, 'Chinstrap': -inf, 'Gentoo': -inf}
# {'Adelie': -15.852764799250032, 'Chinstrap': -inf, 'Gentoo': -inf}
# {'Adelie': -52.02550069905814, 'Chinstrap': -inf, 'Gentoo': -21.617099476900414}
# {'Adelie': -49.71404851580515, 'Chinstrap': -inf, 'Gentoo': -17.343636558763897}
# {'Adelie': -56.73899678070586, 'Chinstrap': -inf, 'Gentoo': -19.940471846021914}
# {'Adelie': -16.97947348501295, 'Chinstrap': -26.53607190744812, 'Gentoo': -inf}
# {'Adelie': -48.664958367911254, 'Chinstrap': -inf, 'Gentoo': -17.755674884566965}
# {'Adelie': -18.61063349396394, 'Chinstrap': -19.866392429799888, 'Gentoo': -inf}
# {'Adelie': -50.17924580401513, 'Chinstrap': -inf, 'Gentoo': -18.260202039651062}
# {'Adelie': -17.22195696130216, 'Chinstrap': -inf, 'Gentoo': -47.338435980247304}
# {'Adelie': -15.798789247442528, 'Chinstrap': -23.022204697809183, 'Gentoo': -inf}
# {'Adelie': -36.44653054288134, 'Chinstrap': -inf, 'Gentoo': -16.991772712698896}
# {'Adelie': -16.534068831261635, 'Chinstrap': -inf, 'Gentoo': -inf}
# {'Adelie': -17.416727813594306, 'Chinstrap': -inf, 'Gentoo': -39.72024815846741}
# {'Adelie': -47.94292558597478, 'Chinstrap': -inf, 'Gentoo': -17.12688250794554}
# {'Adelie': -16.371997099627535, 'Chinstrap': -25.890368239200985, 'Gentoo': -inf}
# {'Adelie': -63.59142183776119, 'Chinstrap': -inf, 'Gentoo': -21.710195242362758}
# {'Adelie': -37.69644996057192, 'Chinstrap': -inf, 'Gentoo': -19.332370105281043}
# {'Adelie': -29.245827615760252, 'Chinstrap': -inf, 'Gentoo': -19.080963061568827}
# {'Adelie': -37.439481480312466, 'Chinstrap': -inf, 'Gentoo': -16.497178100737386}
# {'Adelie': -32.08412733234156, 'Chinstrap': -inf, 'Gentoo': -17.3073522230782}
# {'Adelie': -17.26291690634134, 'Chinstrap': -24.56798441929605, 'Gentoo': -inf}
# {'Adelie': -17.209551676622567, 'Chinstrap': -inf, 'Gentoo': -inf}
# {'Adelie': -28.567086461862555, 'Chinstrap': -19.16595102914533, 'Gentoo': -inf}
# {'Adelie': -17.029073515075257, 'Chinstrap': -27.027040728144442, 'Gentoo': -inf}
# {'Adelie': -27.288072242338473, 'Chinstrap': -inf, 'Gentoo': -18.962337480181997}
# {'Adelie': -34.467468615750484, 'Chinstrap': -inf, 'Gentoo': -19.626270802571497}
# {'Adelie': -16.569581587716847, 'Chinstrap': -inf, 'Gentoo': -inf}
# {'Adelie': -17.027780047177192, 'Chinstrap': -inf, 'Gentoo': -40.9553771491437}
# {'Adelie': -16.374076723888813, 'Chinstrap': -inf, 'Gentoo': -40.433286881439365}
# {'Adelie': -36.01095755291669, 'Chinstrap': -23.04070244655339, 'Gentoo': -inf}
# {'Adelie': -16.89793132213566, 'Chinstrap': -inf, 'Gentoo': -45.42746418604014}
# {'Adelie': -15.791933477427754, 'Chinstrap': -24.64505386701789, 'Gentoo': -inf}
# {'Adelie': -33.82749057302294, 'Chinstrap': -inf, 'Gentoo': -16.34751796408431}
# {'Adelie': -17.838594192508424, 'Chinstrap': -24.858567692254475, 'Gentoo': -inf}
# model's accuracy: 97.10144927536231%
# C:\Users\Dell\anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in log

# %%
showPredict(predictions,y_test)
# Out:
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Chinstrap
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Chinstrap
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
