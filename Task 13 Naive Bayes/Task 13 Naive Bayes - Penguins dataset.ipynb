# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#sns.get_dataset_names()

# %%
df = sns.load_dataset('penguins')
print(df)
labels = np.unique(np.array(df['species']))
labels
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
cnt = df['sex'].value_counts().index[0]
df['sex']=df['sex'].fillna(cnt)
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN    Male
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN    Male
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
df = df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
# Encoding the categorical values with integers
# {'Adelie': 1, 'Chinstrap': 2, 'Gentoo': 3} species
# {'Biscoe': 1, 'Dream': 2, 'Torgersen': 3} islands
# {'Male':1, 'Female':2}
# species=np.unique(df['species'])
# island = np.unique(df['island'])
# idx=1
# d1,d2={},{}
# for s in species:
#     d1[s]=str(idx)
#     idx+=1 

# idx=1
# for i in island:
#     d2[i]=str(idx)
#     idx+=1

# encode={'species':d1,'island':d2,'sex':{'Male':1, 'Female':2}}
# df=df.replace(encode)
# df

# %%
# df.dtypes

# %%
# splitting dataset in 80:20 ratio as train and test set respectively
# species is the response variable i.e. column 0
idx = 8*df.shape[0]//10
df = np.array(df)
np.random.shuffle(df)
x_train=df[:idx,1:]
y_train=df[:idx,0]
x_test=df[idx:,1:] 
y_test=df[idx:,0] 
print("\nx train:\n",x_train)
print("\ny train:\n",y_train)
print("\nx test:\n",x_test)
print("\ny test:\n",y_test)
# Out:
# x train:
#  [['Biscoe' 38.6 17.2 199.0 3750.0 'Female']
#  ['Biscoe' 51.5 16.3 230.0 5500.0 'Male']
#  ['Dream' 40.8 18.9 208.0 4300.0 'Male']
#  ...
#  ['Dream' 39.2 21.1 196.0 4150.0 'Male']
#  ['Biscoe' 43.8 13.9 208.0 4300.0 'Female']
#  ['Biscoe' 37.9 18.6 172.0 3150.0 'Female']]
#
# y train:
#  ['Adelie' 'Gentoo' 'Adelie' 'Gentoo' 'Adelie' 'Chinstrap' 'Adelie'
#  'Adelie' 'Gentoo' 'Chinstrap' 'Gentoo' 'Adelie' 'Adelie' 'Gentoo'
#  'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Adelie' 'Chinstrap' 'Adelie'
#  'Gentoo' 'Chinstrap' 'Gentoo' 'Gentoo' 'Adelie' 'Adelie' 'Chinstrap'
#  'Gentoo' 'Adelie' 'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Chinstrap'
#  'Adelie' 'Chinstrap' 'Adelie' 'Adelie' 'Adelie' 'Gentoo' 'Adelie'
#  'Adelie' 'Gentoo' 'Adelie' 'Chinstrap' 'Chinstrap' 'Adelie' 'Gentoo'
#  'Adelie' 'Adelie' 'Adelie' 'Gentoo' 'Chinstrap' 'Adelie' 'Chinstrap'
#  'Adelie' 'Adelie' 'Gentoo' 'Gentoo' 'Adelie' 'Chinstrap' 'Adelie'
#  'Adelie' 'Adelie' 'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Adelie' 'Gentoo'
#  'Chinstrap' 'Adelie' 'Chinstrap' 'Adelie' 'Gentoo' 'Adelie' 'Adelie'
#  'Adelie' 'Gentoo' 'Gentoo' 'Chinstrap' 'Chinstrap' 'Adelie' 'Adelie'
#  'Gentoo' 'Gentoo' 'Chinstrap' 'Adelie' 'Gentoo' 'Adelie' 'Gentoo'
#  'Gentoo' 'Chinstrap' 'Adelie' 'Gentoo' 'Adelie' 'Adelie' 'Chinstrap'
#  'Gentoo' 'Gentoo' 'Adelie' 'Adelie' 'Chinstrap' 'Gentoo' 'Chinstrap'
#  'Gentoo' 'Adelie' 'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Chinstrap'
#  'Adelie' 'Adelie' 'Adelie' 'Gentoo' 'Gentoo' 'Adelie' 'Adelie' 'Adelie'
#  'Chinstrap' 'Gentoo' 'Gentoo' 'Gentoo' 'Adelie' 'Gentoo' 'Adelie'
#  'Chinstrap' 'Gentoo' 'Adelie' 'Gentoo' 'Gentoo' 'Gentoo' 'Gentoo'
#  'Adelie' 'Adelie' 'Chinstrap' 'Adelie' 'Chinstrap' 'Chinstrap'
#  'Chinstrap' 'Gentoo' 'Chinstrap' 'Gentoo' 'Gentoo' 'Chinstrap' 'Adelie'
#  'Chinstrap' 'Adelie' 'Adelie' 'Gentoo' 'Adelie' 'Adelie' 'Adelie'
#  'Chinstrap' 'Adelie' 'Adelie' 'Gentoo' 'Gentoo' 'Gentoo' 'Chinstrap'
#  'Chinstrap' 'Adelie' 'Adelie' 'Gentoo' 'Gentoo' 'Adelie' 'Adelie'
#  'Chinstrap' 'Gentoo' 'Gentoo' 'Gentoo' 'Gentoo' 'Adelie' 'Gentoo'
#  'Adelie' 'Gentoo' 'Chinstrap' 'Gentoo' 'Chinstrap' 'Adelie' 'Gentoo'
#  'Adelie' 'Gentoo' 'Gentoo' 'Gentoo' 'Adelie' 'Chinstrap' 'Gentoo'
#  'Adelie' 'Adelie' 'Gentoo' 'Adelie' 'Gentoo' 'Gentoo' 'Gentoo' 'Adelie'
#  'Adelie' 'Adelie' 'Chinstrap' 'Gentoo' 'Adelie' 'Gentoo' 'Adelie'
#  'Adelie' 'Adelie' 'Gentoo' 'Adelie' 'Chinstrap' 'Adelie' 'Gentoo'
#  'Gentoo' 'Adelie' 'Gentoo' 'Chinstrap' 'Adelie' 'Gentoo' 'Gentoo'
#  'Chinstrap' 'Chinstrap' 'Adelie' 'Adelie' 'Chinstrap' 'Chinstrap'
#  'Adelie' 'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Gentoo' 'Adelie' 'Gentoo'
#  'Adelie' 'Gentoo' 'Adelie' 'Chinstrap' 'Gentoo' 'Adelie' 'Gentoo'
#  'Adelie' 'Gentoo' 'Gentoo' 'Adelie' 'Chinstrap' 'Adelie' 'Chinstrap'
#  'Chinstrap' 'Gentoo' 'Adelie' 'Chinstrap' 'Gentoo' 'Adelie' 'Chinstrap'
#  'Chinstrap' 'Adelie' 'Adelie' 'Gentoo' 'Adelie' 'Chinstrap' 'Adelie'
#  'Chinstrap' 'Chinstrap' 'Gentoo' 'Gentoo' 'Gentoo' 'Gentoo' 'Adelie'
#  'Gentoo' 'Adelie' 'Adelie' 'Gentoo' 'Adelie']
#
# x test:
#  [['Biscoe' 46.5 14.8 217.0 5200.0 'Female']
#  ['Dream' 54.2 20.8 201.0 4300.0 'Male']
#  ['Biscoe' 44.4 17.3 219.0 5250.0 'Male']
#  ['Dream' 36.5 18.0 182.0 3150.0 'Female']
#  ['Biscoe' 50.4 15.7 222.0 5750.0 'Male']
#  ['Biscoe' 45.3 13.8 208.0 4200.0 'Female']
#  ['Biscoe' 55.9 17.0 228.0 5600.0 'Male']
#  ['Biscoe' 50.0 15.3 220.0 5550.0 'Male']
#  ['Dream' 45.2 17.8 198.0 3950.0 'Female']
#  ['Biscoe' 37.8 20.0 190.0 4250.0 'Male']
#  ['Biscoe' 41.6 18.0 192.0 3950.0 'Male']
#  ['Biscoe' 42.2 19.5 197.0 4275.0 'Male']
#  ['Biscoe' 59.6 17.0 230.0 6050.0 'Male']
#  ['Biscoe' 43.5 14.2 220.0 4700.0 'Female']
#  ['Biscoe' 42.0 13.5 210.0 4150.0 'Female']
#  ['Torgersen' 41.4 18.5 202.0 3875.0 'Male']
#  ['Biscoe' 35.0 17.9 192.0 3725.0 'Female']
#  ['Dream' 43.5 18.1 202.0 3400.0 'Female']
#  ['Dream' 38.3 19.2 189.0 3950.0 'Male']
#  ['Biscoe' 44.9 13.8 212.0 4750.0 'Female']
#  ['Dream' 46.1 18.2 178.0 3250.0 'Female']
#  ['Dream' 49.2 18.2 195.0 4400.0 'Male']
#  ['Biscoe' 48.2 14.3 210.0 4600.0 'Female']
#  ['Biscoe' 47.2 15.5 215.0 4975.0 'Female']
#  ['Biscoe' 52.1 17.0 230.0 5550.0 'Male']
#  ['Dream' 46.9 16.6 192.0 2700.0 'Female']
#  ['Dream' 51.3 19.2 193.0 3650.0 'Male']
#  ['Biscoe' 46.6 14.2 210.0 4850.0 'Female']
#  ['Torgersen' 45.8 18.9 197.0 4150.0 'Male']
#  ['Biscoe' 45.8 14.2 219.0 4700.0 'Female']
#  ['Biscoe' 48.5 15.0 219.0 4850.0 'Female']
#  ['Dream' 39.5 16.7 178.0 3250.0 'Female']
#  ['Dream' 36.3 19.5 190.0 3800.0 'Male']
#  ['Torgersen' 38.9 17.8 181.0 3625.0 'Female']
#  ['Torgersen' 36.7 19.3 193.0 3450.0 'Female']
#  ['Biscoe' 48.5 14.1 220.0 5300.0 'Male']
#  ['Biscoe' 49.1 14.8 220.0 5150.0 'Female']
#  ['Biscoe' 42.7 13.7 208.0 3950.0 'Female']
#  ['Dream' 37.3 17.8 191.0 3350.0 'Female']
#  ['Dream' 50.7 19.7 203.0 4050.0 'Male']
#  ['Biscoe' 40.1 18.9 188.0 4300.0 'Male']
#  ['Dream' 38.9 18.8 190.0 3600.0 'Female']
#  ['Dream' 37.6 19.3 181.0 3300.0 'Female']
#  ['Biscoe' 48.7 15.1 222.0 5350.0 'Male']
#  ['Biscoe' 46.9 14.6 222.0 4875.0 'Female']
#  ['Biscoe' 40.9 13.7 214.0 4650.0 'Female']
#  ['Dream' 39.7 17.9 193.0 4250.0 'Male']
#  ['Biscoe' 41.1 18.2 192.0 4050.0 'Male']
#  ['Biscoe' 52.2 17.1 228.0 5400.0 'Male']
#  ['Biscoe' 45.2 16.4 223.0 5950.0 'Male']
#  ['Biscoe' 45.7 13.9 214.0 4400.0 'Female']
#  ['Dream' 45.9 17.1 190.0 3575.0 'Female']
#  ['Biscoe' 49.9 16.1 213.0 5400.0 'Male']
#  ['Biscoe' 49.4 15.8 216.0 4925.0 'Male']
#  ['Dream' 33.1 16.1 178.0 2900.0 'Female']
#  ['Dream' 40.3 18.5 196.0 4350.0 'Male']
#  ['Biscoe' 49.6 15.0 216.0 4750.0 'Male']
#  ['Biscoe' 36.5 16.6 181.0 2850.0 'Female']
#  ['Torgersen' 34.4 18.4 184.0 3325.0 'Female']
#  ['Dream' 50.8 18.5 201.0 4450.0 'Male']
#  ['Biscoe' 38.1 16.5 198.0 3825.0 'Female']
#  ['Torgersen' 36.6 17.8 185.0 3700.0 'Female']
#  ['Torgersen' 39.6 17.2 196.0 3550.0 'Female']
#  ['Biscoe' 45.2 13.8 215.0 4750.0 'Female']
#  ['Torgersen' 42.9 17.6 196.0 4700.0 'Male']
#  ['Dream' 52.0 19.0 197.0 4150.0 'Male']
#  ['Dream' 46.4 17.8 191.0 3700.0 'Female']
#  ['Dream' 40.7 17.0 190.0 3725.0 'Male']
#  ['Dream' 45.5 17.0 196.0 3500.0 'Female']]
#
# y test:
#  ['Gentoo' 'Chinstrap' 'Gentoo' 'Adelie' 'Gentoo' 'Gentoo' 'Gentoo'
#  'Gentoo' 'Chinstrap' 'Adelie' 'Adelie' 'Adelie' 'Gentoo' 'Gentoo'
#  'Gentoo' 'Adelie' 'Adelie' 'Chinstrap' 'Adelie' 'Gentoo' 'Chinstrap'
#  'Chinstrap' 'Gentoo' 'Gentoo' 'Gentoo' 'Chinstrap' 'Chinstrap' 'Gentoo'
#  'Adelie' 'Gentoo' 'Gentoo' 'Adelie' 'Adelie' 'Adelie' 'Adelie' 'Gentoo'
#  'Gentoo' 'Gentoo' 'Adelie' 'Chinstrap' 'Adelie' 'Adelie' 'Adelie'
#  'Gentoo' 'Gentoo' 'Gentoo' 'Adelie' 'Adelie' 'Gentoo' 'Gentoo' 'Gentoo'
#  'Chinstrap' 'Gentoo' 'Gentoo' 'Adelie' 'Adelie' 'Gentoo' 'Adelie'
#  'Adelie' 'Chinstrap' 'Adelie' 'Adelie' 'Adelie' 'Gentoo' 'Adelie'
#  'Chinstrap' 'Chinstrap' 'Adelie' 'Chinstrap']

# %%
from math import sqrt

#finds mean and standard deviation for each column.Also stores columns 
#with continuous values

def find_stats(x):
    mean,std,columns=[],[],[]
    for col in range(x.shape[1]):
        if isinstance(x[0,col],str)==False:
            mean.append(np.mean(x[:,col]))
            std.append(np.std(x[:,col]))
            columns.append(col)
    return mean,std,columns


#finds log likelihood for category variables
#P(Type|Class)

def find_category_prob(x,y,cls):
    n = x.shape[0]
    probabilities={}
    columns=[]
    probabilities={c:None for c in columns}  
    for col in range(x.shape[1]):
        if isinstance(x[0,col],str):
            types,counts=np.unique(x[:,col],return_counts=True)
            p={t:0 for t in types} #P(Type|Class)
            for r in range(n):
                if y[r]==cls:
                    p[x[r,col]]+=1

            for i in range(types.shape[0]):
                p[types[i]]=np.log(p[types[i]]/counts[i])
            probabilities[col]=p   
        
    return probabilities
    
    
# We find mean and standard deviation for each class
# cls is variable to store the class

def stats_by_class(x,y):
    classes = np.unique(y)
    groups={c:[] for c in classes}
    for row in range(y.shape[0]):
        c = y[row]
        groups[c].append(x[row,:])
    stats={}
    category_prob={}
    for cls,rows in groups.items():
        category_prob[cls]=find_category_prob(x,y,cls)
        mean,std,col = find_stats(np.array(rows))
        stats[cls]=[mean,std,col,len(rows)]
    return stats,category_prob
    
    

    
def gaussian_prob(x_i,mean,std):
    return (1/(sqrt(2*np.pi)*std))*np.exp((-1*(x_i-mean)**2)/(2*(std**2)))



def find_prob_for_class(stats,row,category_prob=None):
    total_rows=0
    for key in stats.keys():
        total_rows+=stats[key][3]
    prob={}
    for cls in stats.keys():
        prob[cls]=np.log(stats[cls][3]/total_rows)
        
        if category_prob is not None:
            d1 = category_prob[cls]
            #print("d1: ",d1)
        for key in d1.keys():
            d2 = d1[key]
            #print("d2: ",d2)
            #print(row[key])
            prob[cls]+=d2[row[key]]
        
        for i in range(len(stats[cls][0])):
            mean = stats[cls][0][i]
            std = stats[cls][1][i]
            idx = stats[cls][2][i]
            #print(mean,std)
            prob[cls]+=np.log(gaussian_prob(row[idx],mean,std))
    return prob


def predict(stats,test_row,category_prob=None):
    posterior=find_prob_for_class(stats,category_prob,test_row)
    #print(prob)
    label,best_posterior=None,None
    for key in posterior.keys():
        if best_posterior is None or best_posterior<posterior[key]:
            best_posterior=posterior[key]
            label=key
    return label



def calAccuracy(pred,y_):
    correct=0
    for i in range(y_.shape[0]):
        if pred[i]==y_[i]:
            correct+=1
    return correct*100/y_.shape[0]



def showPredict(pred,y_):
    for i in range(len(pred)):
        print("predicted: ",pred[i],end="\t")
        print("actual: ",y_[i])

# %%
stats,cat_prob = stats_by_class(x_train,y_train)
predictions=[]
for r in range(x_test.shape[0]):
    label = predict(stats,cat_prob,x_test[r,:])
    predictions.append(label)

accuracy = calAccuracy(predictions, y_test)
print(f"\nmodel's accuracy: {accuracy}%")
# Out:
# model's accuracy: 98.55072463768116%
# C:\Users\Dell\anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: divide by zero encountered in log

# %%
showPredict(predictions,y_test)
# Out:
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Chinstrap
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Adelie	actual:  Adelie
# predicted:  Gentoo	actual:  Gentoo
# predicted:  Adelie	actual:  Adelie
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Chinstrap	actual:  Chinstrap
# predicted:  Adelie	actual:  Adelie
# predicted:  Chinstrap	actual:  Chinstrap

# %%
print(cat_prob)
# Out:
# {'Adelie': {0: {'Biscoe': -1.2840155119994723, 'Dream': -0.7985076962177716, 'Torgersen': 0.0}, 5: {'Female': -0.7744928200138977, 'Male': -0.8023464725249373}}, 'Chinstrap': {0: {'Biscoe': -inf, 'Dream': -0.5978370007556204, 'Torgersen': -inf}, 5: {'Female': -1.556193397915288, 'Male': -1.6445292322453704}}, 'Gentoo': {0: {'Biscoe': -0.32423966818557853, 'Dream': -inf, 'Torgersen': -inf}, 5: {'Female': -1.114360645636249, 'Male': -1.0254900238391471}}}

# %%
stats
# Out:
# {'Adelie': [[38.79516129032259,
#    18.39032258064516,
#    190.00806451612902,
#    3690.1209677419356],
#   [2.632760566362214,
#    1.2492849151284644,
#    6.543275257286052,
#    457.1433316689482],
#   [1, 2, 3, 4],
#   124],
#  'Chinstrap': [[48.963636363636375,
#    18.44727272727273,
#    195.98181818181817,
#    3723.181818181818],
#   [3.344649112530403,
#    1.128450997116207,
#    7.209818832904596,
#    351.38862665451876],
#   [1, 2, 3, 4],
#   55],
#  'Gentoo': [[47.4276595744681,
#    14.958510638297875,
#    216.95744680851064,
#    5093.351063829788],
#   [2.748438793024883,
#    0.9013476405004692,
#    6.537803153732749,
#    496.41233520272374],
#   [1, 2, 3, 4],
#   94]}

# %%
# for col in range(x.shape[1]):
#         if isinstance(x[0,col],str):
#             columns.append(col)

#     class_prob=0
#     for i in range(n):
#         if y[i]==cls:
#             class_prob+=1
#     class_prob/=n
#             p[types[i]]-=np.log(counts[i]/n)
#             p[types[i]]+=np.log(class_prob)
