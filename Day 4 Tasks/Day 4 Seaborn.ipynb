# %%
import seaborn as sns

# %%
df=sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())

# %%
sns.jointplot(x='tip',y='size',data=df,kind='hex')

# %%
sns.jointplot(x='tip',y='size',data=df,kind='reg')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['tip'].value_counts()
# Out:
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 2.83     1
# 1.58     1
# 3.71     1
# 3.35     1
# 2.18     1
# Name: tip, Length: 123, dtype: int64

# %%
sns.distplot(df['tip'])

# %%
sns.countplot('smoker',data=df)

# %%
sns.countplot(y='smoker',data=df)

# %%
sns.boxplot('smoker','tip',data=df)

# %%
sns.boxplot('smoker','tip',data=df,palette='rainbow')

# %%
sns.boxplot(data=df)

# %%
sns.boxplot('day','tip',data=df,hue='smoker',orient='v')

# %%
 sns.violinplot('tip','day',data=df)

# %%
sns.violinplot(data=df)
